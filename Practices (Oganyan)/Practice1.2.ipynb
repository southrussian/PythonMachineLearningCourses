# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn as skl

# %%
arr = np.random.rand(28, 5)

# %%
plt.figure(figsize=(30, 10))
plt.xlabel('point num')
plt.ylabel('point val')
plt.plot(arr)
